# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
topic_model = BERTopic(language='portuguese')   
topic_model.fit_transform(docs)

# %%
topicos = topic_model.get_topic_info()
topicos
# Out:
#      Topic  Count                                    Name  \
# 0       -1   5948                        -1_to_of_the_you
# 1        0   1747                    0_game_team_he_games
# 2        1   1574                        1_car_bike_my_it
# 3        2    760               2_space_nasa_launch_earth
# 4        3    699           3_key_clipper_chip_encryption
# ..     ...    ...                                     ...
# 147    146     10  146_ghostscript_ghostview_pageview_dsc
# 148    147     10        147_drive_model_controller_disks
# 149    148     10           148_duo_machine_sleep_problem
# 150    149     10           149_gun_criminal_frog_article
# 151    150     10          150_cancer_burzynski_cell_moss
#
#                                         Representation  \
# 0       [to, of, the, you, and, is, that, in, it, for]
# 1    [game, team, he, games, hockey, year, season, ...
# 2    [car, bike, my, it, cars, the, engine, on, you...
# 3    [space, nasa, launch, earth, orbit, shuttle, m...
# 4    [key, clipper, chip, encryption, keys, nsa, go...
# ..                                                 ...
# 147  [ghostscript, ghostview, pageview, dsc, page, ...
# 148  [drive, model, controller, disks, floppy, offe...
# 149  [duo, machine, sleep, problem, apple, wake, 23...
# 150  [gun, criminal, frog, article, defend, study, ...
# 151  [cancer, burzynski, cell, moss, therapy, synth...
#
#                                    Representative_Docs
# 0    [\n\n\n\nOh, do please try not to be ludicrous...
# 1    [The FLYERS team that can beat any team on any...
# 2    [Sixteen days I had put off test driving the H...
# 3    [Archive-name: space/groups\nLast-modified: $D...
# 4    [Here is a revised version of my summary which...
# ..                                                 ...
# 147  [What files do I need to download for GhostScr...
# 148  [FOR SALE\n\nPC TOOLS VERSION 7.1\n\nAll origi...
# 149  [\n\n\n\n\nI've had my Duo 230 for a few weeks...
# 150  [\nThere was an interesting column on the edit...
# 151  [A good source of information on Burzynski's m...
#
# [152 rows x 5 columns]

# %%
topicos_esp = topic_model.get_topic(0)
topicos_esp
# Out:
# [('game', 0.012613080447078519),
#  ('team', 0.010762748654801948),
#  ('he', 0.00987226670909161),
#  ('games', 0.008035563978031207),
#  ('hockey', 0.007245038193238484),
#  ('year', 0.007207996348980054),
#  ('season', 0.00701898795176683),
#  ('players', 0.007008126378603099),
#  ('play', 0.006857994192811744),
#  ('was', 0.006384447551552072)]

# %%
topic_model.get_document_info(docs)
# Out:
#                                                 Document  Topic  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      0
# 1      My brother is in the market for a high-perform...     12
# 2      \n\n\n\n\tFinally you said what you dream abou...      8
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...      6
# 4      1)    I have an old Jasmine drive which I cann...      6
# ...                                                  ...    ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...     -1
# 18842  \nNot in isolated ground recepticles (usually ...     87
# 18843  I just installed a DX2-66 CPU in a clone mothe...    103
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...     23
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....      1
#
#                                      Name  \
# 0                    0_game_team_he_games
# 1          12_card_drivers_diamond_driver
# 2       8_armenian_armenians_were_turkish
# 3                 6_scsi_drive_ide_drives
# 4                 6_scsi_drive_ide_drives
# ...                                   ...
# 18841                    -1_to_of_the_you
# 18842               87_uv_light_blue_leds
# 18843               103_cpu_fan_heat_sink
# 18844  23_points_polygon_algorithm_sphere
# 18845                    1_car_bike_my_it
#
#                                           Representation  \
# 0      [game, team, he, games, hockey, year, season, ...
# 1      [card, drivers, diamond, driver, ati, video, c...
# 2      [armenian, armenians, were, turkish, they, was...
# 3      [scsi, drive, ide, drives, disk, hard, control...
# 4      [scsi, drive, ide, drives, disk, hard, control...
# ...                                                  ...
# 18841     [to, of, the, you, and, is, that, in, it, for]
# 18842  [uv, light, blue, leds, led, bulb, bulbs, flas...
# 18843  [cpu, fan, heat, sink, fans, chip, cooling, he...
# 18844  [points, polygon, algorithm, sphere, xxxx, pla...
# 18845  [car, bike, my, it, cars, the, engine, on, you...
#
#                                      Representative_Docs  \
# 0      [The FLYERS team that can beat any team on any...
# 1      [I recently purchased a Diamond Stealth 24 Vid...
# 2      [Accounts of Anti-Armenian Human Rights Violat...
# 3      [\n[ First of all, please edit your postings. ...
# 4      [\n[ First of all, please edit your postings. ...
# ...                                                  ...
# 18841  [\n\n\n\nOh, do please try not to be ludicrous...
# 18842  [\nIn order to emit blue light, a semiconducto...
# 18843  [N(P>Just got a 66MHz 486DX2 system, and am co...
# 18844  [\nSorry!! :-)\n\nCall the four points A, B, C...
# 18845  [Sixteen days I had put off test driving the H...
#
#                                              Top_n_words  Probability  \
# 0      game - team - he - games - hockey - year - sea...     1.000000
# 1      card - drivers - diamond - driver - ati - vide...     1.000000
# 2      armenian - armenians - were - turkish - they -...     0.942470
# 3      scsi - drive - ide - drives - disk - hard - co...     1.000000
# 4      scsi - drive - ide - drives - disk - hard - co...     1.000000
# ...                                                  ...          ...
# 18841  to - of - the - you - and - is - that - in - i...     0.000000
# 18842  uv - light - blue - leds - led - bulb - bulbs ...     0.467035
# 18843  cpu - fan - heat - sink - fans - chip - coolin...     0.887864
# 18844  points - polygon - algorithm - sphere - xxxx -...     1.000000
# 18845  car - bike - my - it - cars - the - engine - o...     1.000000
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 18841                    False
# 18842                    False
# 18843                    False
# 18844                    False
# 18845                    False
#
# [18846 rows x 8 columns]
