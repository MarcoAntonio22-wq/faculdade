# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
docs[0]
# Out:
# "\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n"

# %%
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)

# %%
topicos = topic_model.get_topic_info()
topicos
# Out:
#      Topic  Count                                              Name  \
# 0       -1   6767                                   -1_to_the_of_is
# 1        0   1831                              0_game_team_games_he
# 2        1    604                     1_key_clipper_chip_encryption
# 3        2    524                              2_ites_cheek_yep_huh
# 4        3    293                             3_bike_riding_ride_my
# ..     ...    ...                                               ...
# 217    216     10  216_manhattan_bobbeviceicotekcom_beauchaine_sank
# 218    217     10                  217_wings_flybywire_aircraft_x15
# 219    218     10                          218_hate_sin_love_sinner
# 220    219     10                  219_diamond_drivers_stealth_card
# 221    220     10               220_image_processing_analysis_tools
#
#                                         Representation  \
# 0       [to, the, of, is, and, you, in, for, it, that]
# 1    [game, team, games, he, players, season, hocke...
# 2    [key, clipper, chip, encryption, keys, escrow,...
# 3      [ites, cheek, yep, huh, ken, why, each, of, , ]
# 4    [bike, riding, ride, my, lane, you, car, road,...
# ..                                                 ...
# 217  [manhattan, bobbeviceicotekcom, beauchaine, sa...
# 218  [wings, flybywire, aircraft, x15, sweep, pat, ...
# 219  [hate, sin, love, sinner, hating, our, esau, h...
# 220  [diamond, drivers, stealth, card, video, dougs...
# 221  [image, processing, analysis, tools, plplot, d...
#
#                                    Representative_Docs
# 0    [\n\nI assume you are posting to encourage com...
# 1    [NHL RESULTS FOR GAMES PLAYED 4/15/93.\n\n----...
# 2    [The following document summarizes the Clipper...
# 3    [\nHuh?, \nYep.\n, \n \n                      ...
# 4    [   I need some advice on having someone ride ...
# ..                                                 ...
# 217  [\n  Do I smell .sig material here?\n\n\n/\/\/...
# 218  [\nConfident, or merely crazed?  That desert s...
# 219  [\n   "Hate the sin but love the sinner"...I'v...
# 220  [\nWhile others here may have had better exper...
# 221  [Archive-name: x-faq/part4\nLast-modified: 199...
#
# [222 rows x 5 columns]

# %%
topicos_esp = topic_model.get_topic(0)
topicos_esp
# Out:
# [('game', 0.010302106662462595),
#  ('team', 0.008985718760247842),
#  ('games', 0.007160414456382467),
#  ('he', 0.0069711328304917575),
#  ('players', 0.006307804408272046),
#  ('season', 0.006226819217309757),
#  ('hockey', 0.006091525355641085),
#  ('play', 0.0057595201574555015),
#  ('25', 0.005621186190498394),
#  ('year', 0.0055891585157310944)]

# %%
topic_model.get_document_info(docs)
# Out:
#                                                 Document  Topic  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      0
# 1      My brother is in the market for a high-perform...     -1
# 2      \n\n\n\n\tFinally you said what you dream abou...     54
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...     48
# 4      1)    I have an old Jasmine drive which I cann...     84
# ...                                                  ...    ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...     39
# 18842  \nNot in isolated ground recepticles (usually ...    184
# 18843  I just installed a DX2-66 CPU in a clone mothe...     91
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...    158
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....      8
#
#                                          Name  \
# 0                        0_game_team_games_he
# 1                             -1_to_the_of_is
# 2           54_were_armenians_they_azerbaijan
# 3                     48_scsi_scsi2_scsi1_ide
# 4                  84_tape_backup_tapes_drive
# ...                                       ...
# 18841           39_cancer_medical_gr_medicine
# 18842  184_ground_grounding_conductor_neutral
# 18843                    91_fan_cpu_heat_sink
# 18844            158_den_sphere_radius_points
# 18845                  8_car_cars_ford_engine
#
#                                           Representation  \
# 0      [game, team, games, he, players, season, hocke...
# 1         [to, the, of, is, and, you, in, for, it, that]
# 2      [were, armenians, they, azerbaijan, her, was, ...
# 3      [scsi, scsi2, scsi1, ide, asynchronous, drive,...
# 4      [tape, backup, tapes, drive, munroe, wangdat, ...
# ...                                                  ...
# 18841  [cancer, medical, gr, medicine, doctor, patien...
# 18842  [ground, grounding, conductor, neutral, wire, ...
# 18843  [fan, cpu, heat, sink, fans, cooling, chip, co...
# 18844  [den, sphere, radius, points, plane, ellipse, ...
# 18845  [car, cars, ford, engine, mustang, v8, convert...
#
#                                      Representative_Docs  \
# 0      [NHL RESULTS FOR GAMES PLAYED 4/15/93.\n\n----...
# 1      [\n\nI assume you are posting to encourage com...
# 2      [Accounts of Anti-Armenian Human Right Violati...
# 3      [wlsmith@valve.heart.rri.uwo.ca (Wayne Smith) ...
# 4      [hello all- i have a problem with my micro sol...
# ...                                                  ...
# 18841  [\n   A good source of information on Burzynsk...
# 18842  [\nNot according to the NEC nor the CEC, as ex...
# 18843  [N(P>Just got a 66MHz 486DX2 system, and am co...
# 18844  [\nHere is one by Andrew "Graphics Gems" Glass...
# 18845  [\n\n*nnnnnnnng* Thank you for playing, I cann...
#
#                                              Top_n_words  Probability  \
# 0      game - team - games - he - players - season - ...     1.000000
# 1      to - the - of - is - and - you - in - for - it...     0.000000
# 2      were - armenians - they - azerbaijan - her - w...     0.452657
# 3      scsi - scsi2 - scsi1 - ide - asynchronous - dr...     0.428617
# 4      tape - backup - tapes - drive - munroe - wangd...     0.504253
# ...                                                  ...          ...
# 18841  cancer - medical - gr - medicine - doctor - pa...     1.000000
# 18842  ground - grounding - conductor - neutral - wir...     0.518339
# 18843  fan - cpu - heat - sink - fans - cooling - chi...     1.000000
# 18844  den - sphere - radius - points - plane - ellip...     1.000000
# 18845  car - cars - ford - engine - mustang - v8 - co...     0.983520
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 18841                    False
# 18842                    False
# 18843                    False
# 18844                    False
# 18845                    False
#
# [18846 rows x 8 columns]
